# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good)</span></div>

# %% [markdown]
# ## 1 Some tips and tricks

# %% [markdown]
# ### 1.1 Keyboard Shortcuts

# %% [markdown]
# print('hi')

# %% [markdown]
# ### 1.2 Shell commands

# %%
# !conda install numpy

# %%
# !cd
# Out:
# C:\Users\tiash\OneDrive - National University of Singapore\Documents\SP2273\learning-portfolio-Ting203\using jupyter

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is FC91-6B25
#
#  Directory of C:\Users\tiash\OneDrive - National University of Singapore\Documents\SP2273\learning-portfolio-Ting203\using jupyter
#
# 13/01/2023  08:11 am    <DIR>          .
# 10/01/2023  08:54 am    <DIR>          ..
# 12/01/2023  09:52 pm    <DIR>          .ipynb_checkpoints
# 13/01/2023  08:11 am             3,364 using_jupyter_(good).ipynb
# 12/01/2023  09:44 pm             6,750 using_jupyter_(need).ipynb
#                2 File(s)         10,114 bytes
#                3 Dir(s)  388,207,579,136 bytes free

# %% [markdown]
# ## 2 Jupyter Extensions

# %% [markdown]
# ### 2.1 Installing the extensions

# %%
# !conda install -c conda-forge jupyter_contrib_nbextensions -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\tiash\miniconda3
#
#   added / updated specs:
#     - jupyter_contrib_nbextensions
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyter_contrib_core-0.4.0 |     pyhd8ed1ab_0          18 KB  conda-forge
#     jupyter_contrib_nbextensions-0.7.0|     pyhd8ed1ab_0        20.4 MB  conda-forge
#     jupyter_highlight_selected_word-0.2.0|py310h5588dad_1005          15 KB  conda-forge
#     jupyter_latex_envs-1.4.6   |  pyhd8ed1ab_1002         735 KB  conda-forge
#     jupyter_nbextensions_configurator-0.6.1|     pyhd8ed1ab_0         450 KB  conda-forge
#     libiconv-1.17              |       h8ffe710_0         698 KB  conda-forge
#     libxml2-2.9.14             |       h0ad7f3c_0         1.5 MB
#     libxslt-1.1.35             |       h2bbff1b_0         407 KB
#     lxml-4.9.1                 |  py310h1985fb9_0         918 KB
#     pyyaml-6.0                 |  py310he2412df_4         155 KB  conda-forge
#     yaml-0.2.5                 |       h8ffe710_2          62 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        25.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyter_contrib_c~ conda-forge/noarch::jupyter_contrib_core-0.4.0-pyhd8ed1ab_0
#   jupyter_contrib_n~ conda-forge/noarch::jupyter_contrib_nbextensions-0.7.0-pyhd8ed1ab_0
#   jupyter_highlight~ conda-forge/win-64::jupyter_highlight_selected_word-0.2.0-py310h5588dad_1005
#   jupyter_latex_envs conda-forge/noarch::jupyter_latex_envs-1.4.6-pyhd8ed1ab_1002
#   jupyter_nbextensi~ conda-forge/noarch::jupyter_nbextensions_configurator-0.6.1-pyhd8ed1ab_0
#   libiconv           conda-forge/win-64::libiconv-1.17-h8ffe710_0
#   libxml2            pkgs/main/win-64::libxml2-2.9.14-h0ad7f3c_0
#   libxslt            pkgs/main/win-64::libxslt-1.1.35-h2bbff1b_0
#   lxml               pkgs/main/win-64::lxml-4.9.1-py310h1985fb9_0
#   pyyaml             conda-forge/win-64::pyyaml-6.0-py310he2412df_4
#   yaml               conda-forge/win-64::yaml-0.2.5-h8ffe710_2
#
#
#
# Downloading and Extracting Packages
#
# jupyter_latex_envs-1 | 735 KB    |            |   0%
#
# libiconv-1.17        | 698 KB    |            |   0%
#
#
# jupyter_contrib_core | 18 KB     |            |   0%
#
#
#
# jupyter_nbextensions | 450 KB    |            |   0%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    |            |   0%
#
#
#
#
#
# jupyter_highlight_se | 15 KB     |            |   0%
#
#
#
#
#
#
# yaml-0.2.5           | 62 KB     |            |   0%
#
#
#
#
#
#
#
# lxml-4.9.1           | 918 KB    |            |   0%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   |            |   0%
#
#
#
#
#
#
#
#
#
# pyyaml-6.0           | 155 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# libxslt-1.1.35       | 407 KB    |            |   0%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | 1          |   1%
#
# libiconv-1.17        | 698 KB    | 2          |   2%
# jupyter_latex_envs-1 | 735 KB    | 2          |   2%
#
#
#
# jupyter_nbextensions | 450 KB    | 3          |   4%
#
#
# jupyter_contrib_core | 18 KB     | #########  |  91%
#
# libiconv-1.17        | 698 KB    | ##9        |  30%
#
#
#
# jupyter_nbextensions | 450 KB    | ###1       |  32%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | #7         |  18%
# jupyter_latex_envs-1 | 735 KB    | #7         |  17%
#
#
# jupyter_contrib_core | 18 KB     | ########## | 100%
#
#
#
#
#
# jupyter_highlight_se | 15 KB     | ########## | 100%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | ###1       |  31%
#
#
#
#
#
# jupyter_highlight_se | 15 KB     | ########## | 100%
#
# libiconv-1.17        | 698 KB    | ####8      |  48%
#
#
#
#
#
#
# yaml-0.2.5           | 62 KB     | ##5        |  26%
#
#
#
# jupyter_nbextensions | 450 KB    | ######     |  60%
# jupyter_latex_envs-1 | 735 KB    | ####1      |  41%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | ####2      |  43%
#
# libiconv-1.17        | 698 KB    | #######3   |  73%
#
#
#
#
#
#
# yaml-0.2.5           | 62 KB     | ########## | 100%
#
#
#
# jupyter_nbextensions | 450 KB    | ########8  |  89%
# jupyter_latex_envs-1 | 735 KB    | ######3    |  63%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | ######3    |  64%
#
# libiconv-1.17        | 698 KB    | #########4 |  94%
#
#
#
#
#
#
#
# lxml-4.9.1           | 918 KB    | 1          |   2%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   |            |   0%
# jupyter_latex_envs-1 | 735 KB    | ########7  |  87%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | #######9   |  79%
#
#
#
#
#
#
#
# lxml-4.9.1           | 918 KB    | #7         |  17%
#
#
#
# jupyter_nbextensions | 450 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   |            |   1%
#
#
#
#
#
#
#
# lxml-4.9.1           | 918 KB    | ####8      |  49%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | 1          |   1%
#
# libiconv-1.17        | 698 KB    | ########## | 100%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
# libxslt-1.1.35       | 407 KB    | 3          |   4%
#
#
#
#
#
#
#
# lxml-4.9.1           | 918 KB    | #########  |  91%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libxslt-1.1.35       | 407 KB    | #####9     |  59%
#
#
#
#
#
#
#
#
#
# pyyaml-6.0           | 155 KB    | #          |  10%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | 2          |   3%
# jupyter_latex_envs-1 | 735 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | 4          |   4%
#
#
#
#
# libxml2-2.9.14       | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | 7          |   7%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
# libxslt-1.1.35       | 407 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libxslt-1.1.35       | 407 KB    | ########## | 100%
#
#
#
#
#
#
#
# lxml-4.9.1           | 918 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# pyyaml-6.0           | 155 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# pyyaml-6.0           | 155 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #3         |  14%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #6         |  17%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##         |  20%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##2        |  23%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##6        |  26%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ##9        |  29%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ####1      |  41%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #####      |  50%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #####9     |  59%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ######8    |  68%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #######    |  71%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #######6   |  77%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #######9   |  80%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #########1 |  91%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #########3 |  94%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
# jupyter_contrib_nbex | 20.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done

# %% [markdown]
# ### 2.2 Enabling the extensions

# %%
# !conda install autopep8 -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\tiash\miniconda3
#
#   added / updated specs:
#     - autopep8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     autopep8-1.6.0             |     pyhd3eb1b0_1          43 KB
#     pycodestyle-2.10.0         |  py310haa95532_0          87 KB
#     toml-0.10.2                |     pyhd3eb1b0_0          20 KB
#     ------------------------------------------------------------
#                                            Total:         149 KB
#
# The following NEW packages will be INSTALLED:
#
#   autopep8           pkgs/main/noarch::autopep8-1.6.0-pyhd3eb1b0_1
#   pycodestyle        pkgs/main/win-64::pycodestyle-2.10.0-py310haa95532_0
#   toml               pkgs/main/noarch::toml-0.10.2-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/win-64::certifi-2022.12.7-py310haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# toml-0.10.2          | 20 KB     |            |   0%
#
# pycodestyle-2.10.0   | 87 KB     |            |   0%
#
#
# autopep8-1.6.0       | 43 KB     |            |   0%
# toml-0.10.2          | 20 KB     | ########   |  81%
#
#
# autopep8-1.6.0       | 43 KB     | ###7       |  38%
# toml-0.10.2          | 20 KB     | ########## | 100%
#
#
# autopep8-1.6.0       | 43 KB     | ########## | 100%
#
# pycodestyle-2.10.0   | 87 KB     | #8         |  18%
#
# pycodestyle-2.10.0   | 87 KB     | ########## | 100%
#
# pycodestyle-2.10.0   | 87 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ## 3 Shell Magic

# %%
# %timeit x=10
# Out:
# 20.7 ns ± 0.407 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit 
x=10
y=10
z=10
# Out:
# 37.7 ns ± 1.67 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ## 4 The Kernel

# %% [markdown]
# ## Exercise 1 :  A new shortcut

# %% [markdown]
# # Your solution here
